# %%
import pandas as pd

# %%
# Load the dataset from a CSV file
file_path = 'data/java_test_dataset.csv'
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78388 entries, 0 to 78387
# Data columns (total 38 columns):
# repo_id                                78388 non-null int64
# url                                    78388 non-null object
# language                               49422 non-null object
# fork_count                             78388 non-null int64
# stargazer_count                        78388 non-null int64
# focal_class_identifier                 78388 non-null object
# focal_class_superclass                 21448 non-null object
# focal_class_interfaces                 31320 non-null object
# focal_class_fields                     78388 non-null object
# focal_class_methods                    78388 non-null object
# focal_class_file                       78388 non-null object
# focal_method_identifier                78388 non-null object
# focal_method_parameters                78388 non-null object
# focal_method_modifiers                 75869 non-null object
# focal_method_return                    77672 non-null object
# focal_method_body                      78388 non-null object
# focal_method_signature                 78388 non-null object
# focal_method_full_signature            78388 non-null object
# focal_method_class_method_signature    78388 non-null object
# focal_method_testcase                  78388 non-null bool
# focal_method_constructor               78388 non-null bool
# focal_method_invocations               78388 non-null object
# test_class_identifier                  78388 non-null object
# test_class_superclass                  14522 non-null object
# test_class_interfaces                  505 non-null object
# test_class_fields                      78388 non-null object
# test_class_file                        78388 non-null object
# test_case_identifier                   78385 non-null object
# test_case_parameters                   78350 non-null object
# test_case_modifiers                    78388 non-null object
# test_case_return                       78388 non-null object
# test_case_body                         78388 non-null object
# test_case_signature                    78388 non-null object
# test_case_full_signature               78388 non-null object
# test_case_class_method_signature       78388 non-null object
# test_case_testcase                     78388 non-null bool
# test_case_constructor                  78388 non-null bool
# test_case_invocations                  78388 non-null object
# dtypes: bool(4), int64(3), object(31)
# memory usage: 20.6+ MB

# %%
def format_java_test_class(row):
    # Class definition
    class_def = f"public class {row['test_class_identifier']}"

    # Superclass
    if pd.notna(row['test_class_superclass']):
        class_def += f" extends {row['test_class_superclass']}"

    # Interfaces
    if pd.notna(row['test_class_interfaces']):
        class_def += f" implements {row['test_class_interfaces']}"

    class_def += " {\n"

    # Fields
    fields = row['test_class_fields'].split(';')  # Assuming fields are separated by semicolons
    for field in fields:
        class_def += f"    {field};\n"

    # Test case
    test_case = f"""
    {row['test_case_modifiers']} {row['test_case_return']} {row['test_case_identifier']}({row['test_case_parameters']}) {{
        {row['test_case_body']}
    }}
    """
    class_def += test_case

    # Closing class definition
    class_def += "\n}"

    return class_def.strip()

# %%
def format_java_focal_class(row):
    # Class definition
    class_def = f"public class {row['focal_class_identifier']}"

    # Superclass
    if pd.notna(row['focal_class_superclass']):
        class_def += f" extends {row['focal_class_superclass']}"

    # Interfaces
    if pd.notna(row['focal_class_interfaces']):
        class_def += f" implements {row['focal_class_interfaces']}"

    class_def += " {\n"

    # Fields
    fields = row['focal_class_fields'].split(';')  # Assuming fields are separated by semicolons
    for field in fields:
        class_def += f"    {field};\n"

    # Focal method
    focal_method = f"""
    {row['focal_case_modifiers']} {row['focal_case_return']} {row['focal_case_identifier']}({row['focal_case_parameters']}) {{
        {row['focal_case_body']}
    }}
    """
    class_def += focal_method

    # Closing class definition
    class_def += "\n}"

    return class_def.strip()

# %%
# Function to assemble the Java focal class code for each row
def assemble_focal_class_code(row):
    class_template = f"""
public class {row['focal_class_identifier']} {{
    {row['focal_class_fields']}
    
    {row['focal_class_methods']}
}}
"""
    return class_template.strip()

# Function to assemble the Java test case code for each row
def assemble_test_case_code(row):
    # Assuming 'test_case_body' contains formatted test cases
    # and 'focal_class_identifier' is used to name the test class
    test_class_template = f"""
class {row['focal_class_identifier']}Test {{
    {row['test_case_body']}
}}
"""
    return test_class_template.strip()

# Apply the functions to each row to create the separate Java code parts
df['focal_class_code'] = df.apply(assemble_focal_class_code, axis=1)
df['test_case_code'] = df.apply(assemble_test_case_code, axis=1)

# Optionally, save to a new CSV file
new_file_path = 'java_test_dataset_assembeled.csv'
df[['focal_class_code', 'test_case_code']].to_csv(new_file_path, index=False)

print(f"Dataset with separated Java focal class and test case code saved to {new_file_path}")
# Out:
# Dataset with separated Java focal class and test case code saved to java_test_dataset_assembeled.csv

# %%
df.head()
# Out:
#     repo_id                                                url language  \
# 0  58314354  https://github.com/bytefish/JavaElasticSearchE...     Java
# 1  58314354  https://github.com/bytefish/JavaElasticSearchE...     Java
# 2  58314354  https://github.com/bytefish/JavaElasticSearchE...     Java
# 3  58314354  https://github.com/bytefish/JavaElasticSearchE...     Java
# 4  58314354  https://github.com/bytefish/JavaElasticSearchE...     Java
#
#    fork_count  stargazer_count        focal_class_identifier  \
# 0          11                0  IgnoreMissingValuesConverter
# 1          11                0                 DateUtilities
# 2          11                0                 DateUtilities
# 3          11                0                 DateUtilities
# 4          11                0     LocalWeatherDataConverter
#
#   focal_class_superclass            focal_class_interfaces  \
# 0                    NaN  implements ITypeConverter<Float>
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#                                   focal_class_fields  \
# 0  [{'original_string': 'private List<String> mis...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                  focal_class_methods  ...  \
# 0  [{'identifier': 'IgnoreMissingValuesConverter'...  ...
# 1  [{'identifier': 'from', 'parameters': '(LocalD...  ...
# 2  [{'identifier': 'from', 'parameters': '(LocalD...  ...
# 3  [{'identifier': 'from', 'parameters': '(LocalD...  ...
# 4  [{'identifier': 'convert', 'parameters': '(csv...  ...
#
#   test_case_parameters test_case_modifiers test_case_return  \
# 0                   ()        @Test public             void
# 1                   ()        @Test public             void
# 2                   ()        @Test public             void
# 3                   ()        @Test public             void
# 4                   ()        @Test public             void
#
#                                       test_case_body  \
# 0  @Test\n    public void returns_null_if_value_i...
# 1  @Test\n    public void generated_date_has_utc_...
# 2  @Test\n    public void generated_date_has_give...
# 3  @Test\n    public void generated_date_has_give...
# 4  @Test\n    public void testConvert() throws Ex...
#
#                                  test_case_signature  \
# 0            void returns_null_if_value_is_missing()
# 1  void generated_date_has_utc_offset_when_none_i...
# 2  void generated_date_has_given_offset_when_offs...
# 3  void generated_date_has_given_timezone_when_gi...
# 4                                 void testConvert()
#
#                             test_case_full_signature  \
# 0  @Test public void returns_null_if_value_is_mis...
# 1  @Test public void generated_date_has_utc_offse...
# 2  @Test public void generated_date_has_given_off...
# 3  @Test public void generated_date_has_given_tim...
# 4                    @Test public void testConvert()
#
#                     test_case_class_method_signature test_case_testcase  \
# 0  IgnoreMissingValuesConverterTest.returns_null_...               True
# 1  DateUtilitiesTest.generated_date_has_utc_offse...               True
# 2  DateUtilitiesTest.generated_date_has_given_off...               True
# 3  DateUtilitiesTest.generated_date_has_given_tim...               True
# 4        LocalWeatherDataConverterTest.testConvert()               True
#
#   test_case_constructor                              test_case_invocations
# 0                 False  ['assertEquals', 'convert', 'assertEquals', 'c...
# 1                 False  ['of', 'of', 'atTime', 'atOffset', 'from', 'as...
# 2                 False  ['of', 'of', 'ofHours', 'atTime', 'atOffset', ...
# 3                 False  ['of', 'of', 'atTime', 'ofHours', 'atOffset', ...
# 4                 False  ['setWban', 'setDate', 'of', 'setTime', 'of', ...
#
# [5 rows x 38 columns]

# %%
print(format_java_test_class(df.iloc[0]))
# Out:
# public class IgnoreMissingValuesConverterTest {
#     [];
#
#     @Test public void returns_null_if_value_is_missing(()) {
#         @Test
#     public void returns_null_if_value_is_missing() throws Exception {
#
#         IgnoreMissingValuesConverter converter = new IgnoreMissingValuesConverter("M", "m");
#
#         Assert.assertEquals(null, converter.convert(""));
#         Assert.assertEquals(null, converter.convert("M"));
#         Assert.assertEquals(null, converter.convert("m"));
#
#         Assert.assertEquals(1.0f, converter.convert("1.0"), 1e-3);
#     }
#     }
#
# }

# %%
print(format_java_focal_class(df.iloc[0]))
# Out:
# No match found for method: '[{'identifier': 'IgnoreMissingValuesConverter', 'parameters': '(String... missingValueRepresentation)', 'modifiers': 'public', 'return': '', 'signature': ' IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'full_signature': 'public  IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'class_method_signature': 'IgnoreMissingValuesConverter.IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'testcase': False, 'constructor': True}, {'identifier': 'IgnoreMissingValuesConverter', 'parameters': '(List<String> missingValueRepresentation)', 'modifiers': 'public', 'return': '', 'signature': ' IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'full_signature': 'public  IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'class_method_signature': 'IgnoreMissingValuesConverter.IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'testcase': False, 'constructor': True}, {'identifier': 'convert', 'parameters': '(final String s)', 'modifiers': '@Override public', 'return': 'Float', 'signature': 'Float convert(final String s)', 'full_signature': '@Override public Float convert(final String s)', 'class_method_signature': 'IgnoreMissingValuesConverter.convert(final String s)', 'testcase': False, 'constructor': False}, {'identifier': 'getTargetType', 'parameters': '()', 'modifiers': '@Override public', 'return': 'Type', 'signature': 'Type getTargetType()', 'full_signature': '@Override public Type getTargetType()', 'class_method_signature': 'IgnoreMissingValuesConverter.getTargetType()', 'testcase': False, 'constructor': False}]' in class: 'IgnoreMissingValuesConverter'
# public class IgnoreMissingValuesConverter implements implements ITypeConverter<Float> {
#     [{'original_string': 'private List<String> missingValueRepresentation;
#     ', 'modifier': 'private', 'type': 'List<String>', 'declarator': 'missingValueRepresentation', 'var_name': 'missingValueRepresentation'}];
# }

# %%
import pandas as pd

row_to_print = df.iloc[0]

for column in df.columns:
    print(f"\n\033[1m{column}\033[0m: {row_to_print[column]}\n")
# Out:
# repo_id: 58314354
#
#
# url: https://github.com/bytefish/JavaElasticSearchExperiment
#
#
# language: Java
#
#
# fork_count: 11
#
#
# stargazer_count: 0
#
#
# focal_class_identifier: IgnoreMissingValuesConverter
#
#
# focal_class_superclass: nan
#
#
# focal_class_interfaces: implements ITypeConverter<Float>
#
#
# focal_class_fields: [{'original_string': 'private List<String> missingValueRepresentation;', 'modifier': 'private', 'type': 'List<String>', 'declarator': 'missingValueRepresentation', 'var_name': 'missingValueRepresentation'}]
#
#
# focal_class_methods: [{'identifier': 'IgnoreMissingValuesConverter', 'parameters': '(String... missingValueRepresentation)', 'modifiers': 'public', 'return': '', 'signature': ' IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'full_signature': 'public  IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'class_method_signature': 'IgnoreMissingValuesConverter.IgnoreMissingValuesConverter(String... missingValueRepresentation)', 'testcase': False, 'constructor': True}, {'identifier': 'IgnoreMissingValuesConverter', 'parameters': '(List<String> missingValueRepresentation)', 'modifiers': 'public', 'return': '', 'signature': ' IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'full_signature': 'public  IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'class_method_signature': 'IgnoreMissingValuesConverter.IgnoreMissingValuesConverter(List<String> missingValueRepresentation)', 'testcase': False, 'constructor': True}, {'identifier': 'convert', 'parameters': '(final String s)', 'modifiers': '@Override public', 'return': 'Float', 'signature': 'Float convert(final String s)', 'full_signature': '@Override public Float convert(final String s)', 'class_method_signature': 'IgnoreMissingValuesConverter.convert(final String s)', 'testcase': False, 'constructor': False}, {'identifier': 'getTargetType', 'parameters': '()', 'modifiers': '@Override public', 'return': 'Type', 'signature': 'Type getTargetType()', 'full_signature': '@Override public Type getTargetType()', 'class_method_signature': 'IgnoreMissingValuesConverter.getTargetType()', 'testcase': False, 'constructor': False}]
#
#
# focal_class_file: JavaElasticSearchExperiment/src/main/java/csv/converter/IgnoreMissingValuesConverter.java
#
#
# focal_method_identifier: convert
#
#
# focal_method_parameters: (final String s)
#
#
# focal_method_modifiers: @Override public
#
#
# focal_method_return: Float
#
#
# focal_method_body: @Override
#     public Float convert(final String s) {
#
#         if(StringUtils.isNullOrWhiteSpace(s)) {
#             return null;
#         }
#
#         boolean isMissingValue = missingValueRepresentation
#                 .stream()
#                 .anyMatch(x -> x.equals(s));
#
#         if(isMissingValue) {
#             return null;
#         }
#
#         return Float.parseFloat(s);
#     }
#
#
# focal_method_signature: Float convert(final String s)
#
#
# focal_method_full_signature: @Override public Float convert(final String s)
#
#
# focal_method_class_method_signature: IgnoreMissingValuesConverter.convert(final String s)
#
#
# focal_method_testcase: False
#
#
# focal_method_constructor: False
#
#
# focal_method_invocations: ['isNullOrWhiteSpace', 'anyMatch', 'stream', 'equals', 'parseFloat']
#
#
# test_class_identifier: IgnoreMissingValuesConverterTest
#
#
# test_class_superclass: nan
#
#
# test_class_interfaces: nan
#
#
# test_class_fields: []
#
#
# test_class_file: JavaElasticSearchExperiment/src/test/java/csv/converter/IgnoreMissingValuesConverterTest.java
#
#
# test_case_identifier: returns_null_if_value_is_missing
#
#
# test_case_parameters: ()
#
#
# test_case_modifiers: @Test public
#
#
# test_case_return: void
#
#
# test_case_body: @Test
#     public void returns_null_if_value_is_missing() throws Exception {
#
#         IgnoreMissingValuesConverter converter = new IgnoreMissingValuesConverter("M", "m");
#
#         Assert.assertEquals(null, converter.convert(""));
#         Assert.assertEquals(null, converter.convert("M"));
#         Assert.assertEquals(null, converter.convert("m"));
#
#         Assert.assertEquals(1.0f, converter.convert("1.0"), 1e-3);
#     }
#
#
# test_case_signature: void returns_null_if_value_is_missing()
#
#
# test_case_full_signature: @Test public void returns_null_if_value_is_missing()
#
#
# test_case_class_method_signature: IgnoreMissingValuesConverterTest.returns_null_if_value_is_missing()
#
#
# test_case_testcase: True
#
#
# test_case_constructor: False
#
#
# test_case_invocations: ['assertEquals', 'convert', 'assertEquals', 'convert', 'assertEquals', 'convert', 'assertEquals', 'convert']
